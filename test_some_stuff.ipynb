# %%
#basic html reguest to get the html code of a website and print it out 
import urllib.request
import urllib.parse
import urllib.error
url = 'https://v5.bvg.transport.rest/locations?query=alexander&results=3&fuzzy=true'
html = urllib.request.urlopen(url).read()
print(html.decode())
# Out:
# [
# 	{
# 		"type": "stop",
# 		"id": "900000012156",
# 		"name": "Alexandrinenstr.",
# 		"location": {
# 			"type": "location",
# 			"id": "900012156",
# 			"latitude": 52.505157,
# 			"longitude": 13.405326
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": false,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:11000:900012156"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900000100003",
# 		"name": "S+U Alexanderplatz",
# 		"location": {
# 			"type": "location",
# 			"id": "900100003",
# 			"latitude": 52.521508,
# 			"longitude": 13.411267
# 		},
# 		"products": {
# 			"suburban": true,
# 			"subway": true,
# 			"tram": true,
# 			"bus": true,
# 			"ferry": false,
# 			"express": false,
# 			"regional": true
# 		},
# 		"stationDHID": "de:11000:900100003"
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900000100731",
# 		"name": "S+U Alexanderpl/Memhardstr.",
# 		"location": {
# ...

# %%
import json
url = 'https://v5.bvg.transport.rest/stops/nearby?latitude=52.520658&longitude=13.411875&results=20'
html = urllib.request.urlopen(url).read()
x= json.loads(html) #make json from html
print(len(x))
print(html.decode())
# Out:
# 18
# [
# 	{
# 		"type": "stop",
# 		"id": "900000100026",
# 		"name": "S+U Alexanderplatz/Gontardstr.",
# 		"location": {
# 			"type": "location",
# 			"id": "900100026",
# 			"latitude": 52.52105,
# 			"longitude": 13.411285
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": true,
# 			"bus": false,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:11000:900100026",
# 		"distance": 59
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900000100024",
# 		"name": "S+U Alexanderplatz/Dircksenstr.",
# 		"location": {
# 			"type": "location",
# 			"id": "900100024",
# 			"latitude": 52.521481,
# 			"longitude": 13.411924
# 		},
# 		"products": {
# 			"suburban": false,
# 			"subway": false,
# 			"tram": true,
# 			"bus": false,
# 			"ferry": false,
# 			"express": false,
# 			"regional": false
# 		},
# 		"stationDHID": "de:11000:900100024",
# 		"distance": 92
# 	},
# 	{
# 		"type": "stop",
# 		"id": "900000100003",
# ...

# %%
import telegram
from telegram.ext import Updater, CommandHandler, MessageHandler, Filters

def start(update, context):
    context.bot.send_message(chat_id=update.effective_chat.id, text="Hello! What's your name?")

def echo(update, context):
    user_input = update.message.text
    context.bot.send_message(chat_id=update.effective_chat.id, text="Hi, "+user_input+"!")

def main():
    updater = Updater(token='6027981425:AAHdSWkDWAgxMvZZTdXXKmoTK6eo_JJmTto', use_context=True)
    dispatcher = updater.dispatcher
    dispatcher.add_handler(CommandHandler('start', start))
    dispatcher.add_handler(MessageHandler(Filters.text & ~Filters.command, echo))
    updater.start_polling(poll_interval=0.5)
# Out:
# Error while getting Updates: Conflict: terminated by other getUpdates request; make sure that only one bot instance is running
# No error handlers are registered, logging exception.
# Traceback (most recent call last):
#   File "C:\Users\alexb\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\telegram\ext\updater.py", line 646, in _network_loop_retry
#     if not action_cb():
#   File "C:\Users\alexb\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\telegram\ext\updater.py", line 597, in polling_action_cb
#     updates = self.bot.get_updates(
#   File "C:\Users\alexb\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\telegram\ext\extbot.py", line 222, in get_updates
#     updates = super().get_updates(
# ...
